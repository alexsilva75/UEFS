# %% [markdown]
# Algoritmos

# %%
#The first byte of the record stores the size.
#The string values are encoded using utf-8,
#which can use more bytes than the number of
#characters of the string.
class Record:
  def __init__(self, record_size, value=""):
    self.byte_array = bytearray([0] * record_size)
    self.write(value)

  # creates a record from a bytearray
  def create(record_size, byte_array):
    string_bytes = byte_array[1:1+byte_array[0]]
    return Record(record_size, string_bytes.decode('utf-8'))

  def write(self, value):
    if(not isinstance(value, str)):
       raise TypeError(f"The value must be str!")

    string_bytes = value.encode('utf-8')

    if (1+len(string_bytes))> len(self.byte_array):
      raise ValueError(f"Record overflow!")

    self.byte_array[0] = len(string_bytes)
    self.byte_array[1:1+len(string_bytes)] = string_bytes

  def read(self):
    string_bytes = self.byte_array[1:1+self.byte_array[0]]
    return string_bytes.decode('utf-8')

  def size(self):
    return len(self.byte_array)

  def bytes(self):
    return self.byte_array.copy()

  def __str__(self):
    return f"value:{self.read()}, bytes occupied:{1+self.byte_array[0]} , capacity:{self.size()}"

# %%
rec = Record(6,"joão")
print(rec.bytes())
print(rec)
# Out:
# bytearray(b'\x05jo\xc3\xa3o')
# value:joão, bytes occupied:6 , capacity:6

# %%
# Block and Page are synomyms
class Block:
  def __init__(self, block_size, record_size):
    self.records = []
    self.block_size = block_size
    self.record_size = record_size
    self.capacity = (block_size-1) // record_size

  # creates a block from a bytearray
  def create(block_size, record_size, byte_array):
    block = Block(block_size, record_size)

    pos = 1
    for _ in range(byte_array[0]):
      rec = Record.create(record_size, byte_array[pos:pos+record_size] )
      block.add(rec.read())
      pos += record_size

    return block

  def add(self, key):
    if(not isinstance(key, str)):
       raise TypeError(f"The key must be str!")

    if(self.size() < self.capacity):
      self.records.append(Record(self.record_size, key))
    else:
      raise ValueError("The block is full!")

  def addIndex(self, index, key):
    if(not isinstance(key, str)):
       raise TypeError(f"The key must be str!")

    if(self.size() < self.capacity):
      self.records.insert(index, Record(self.record_size, key))
    else:
      raise ValueError("The block is full!")

  def remove(self, key):
    if(not isinstance(key, str)):
       raise TypeError(f"The key must be str!")

    rec = self.search(key)
    if(rec):
      return self.records.remove(rec)
    return None

  def removeIndex(self, index):
    if(not isinstance(index, int)):
       raise TypeError(f"The index must be int!")
    return self.records.pop(index)

  def removeLast(self):
    if len(self.records)>0:
      return self.records.pop()
    return None

  def read(self):
    str=""
    for rec in self.records:
      str += rec.read() + "\n"
    return str;

  def search(self, key):
    if(not isinstance(key, str)):
       raise TypeError(f"The key must be str!")

    for i in range(len(self.records)):
      if(self.getRecord(i).read()==key):
        return i
    return -1

  # returns a list of records, within the range keyA (inclusive) and KeyB (exclusive)
  def rangeSearch(self, keyA, keyB):
    if((not isinstance(keyA, str)) or (not isinstance(keyB, str))):
       raise TypeError(f"The key must be str!")

    ret = []
    for rec in self.records:
      recValue = rec.read()
      if(recValue>=keyA and recValue<keyB):
        ret.append(recValue)
    return ret

  def getRecord(self, index):
    return self.records[index]

  def size(self):
    return len(self.records)

  def isFull(self):
    return self.size()==self.capacity

  def bytes(self):
    byte_array = bytearray([0] * self.block_size)
    byte_array[0] = self.size()
    pos = 1
    for rec in self.records:
      byte_array[pos:pos+rec.size()] = rec.bytes()
      pos += rec.size()

    return byte_array

# %%
block = Block(64, 4)
print(f"block capacity: {block.capacity}")
print(f"block size: {block.size()}")

block.add("V1")
block.add("V2")
block.add("V3")
block.add("V5")
block.add("V6")
block.add("V7")

block.addIndex(2, "V22")
block.removeLast()

print(block.read())

print(f"getRecord(0): {block.getRecord(0)}")
print(f"search: {block.search('V5')}")
print(f"range search: {block.rangeSearch('V3','V7')}")
print(f"block bytes: {block.bytes()}")
# Out:
# block capacity: 15
# block size: 0
# V1
# V2
# V22
# V3
# V5
# V6
#
# getRecord(0): value:V1, bytes occupied:3 , capacity:4
# search: 4
# range search: ['V3', 'V5', 'V6']
# block bytes: bytearray(b'\x06\x02V1\x00\x02V2\x00\x03V22\x02V3\x00\x02V5\x00\x02V6\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')

# %%
import os
class HeapFile:

  def __init__(self, filename, block_size, record_size):
    self.filename = filename
    self.block_size = block_size
    self.record_size = record_size

    #print(f"os.path.abspath(filename): {os.path.abspath(filename)}")

    if(os.path.exists(filename)):
      self.blocks = os.path.getsize(filename)//block_size
    else:
      self.blocks = 1
      with open(self.filename, "wb") as file:
        file.write(Block(block_size, record_size).bytes())

  def add(self, key):
    block = self.read(self.blocks-1)

    if(block.isFull()):
      self.blocks+=1
      block = Block(self.block_size, self.record_size)

    block.add(key)
    self.write(self.blocks-1, block)

  def remove(self, key):
    (block_id, rec_id) = self.search(key)
    if block_id>=0:
      block = self.read(block_id)
      block.removeIndex(rec_id)
      self.write(block_id, block)

  def scan(self, output=True):
    for i in range(self.blocks):
      if output:
        print(self.read(i).read())
      else:
        self.read(i).read()

  # returns the record, containing the key
  def search(self, key):
    for i in range(self.blocks):
      block = self.read(i)
      rec_id = block.search(key)

      if(rec_id>=0):
        return (i, rec_id)
    return (-1, -1)

  # returns a list of records, within the range keyA (inclusive) and KeyB (exclusive)
  def rangeSearch(self, keyA, keyB):
    result = []
    for i in range(self.blocks):
      result += self.read(i).rangeSearch(keyA, keyB)
    return result

  def write(self, block_id, block):
    if(not isinstance(block, Block)):
       raise TypeError(f"The block must by of Block type!")

    with open(self.filename, "r+b") as file:
      file.seek(self.block_size * (block_id))
      file.write(block.bytes())

  def read(self, block_id):
    with open(self.filename, "r+b") as file:
      file.seek(self.block_size *(block_id))
      byte_array = file.read(self.block_size)
      return Block.create(self.block_size, self.record_size, byte_array)

# %%
filename  = "heapfile.bin"
fileType = HeapFile(filename, 16, 4)

fileType.add("V1")
fileType.add("V2")
fileType.add("V3")

fileType.add("V4")
fileType.add("V5")
fileType.add("V6")

fileType.add("V7")
fileType.add("V8")

fileType.scan()

print(f"blocks:{fileType.blocks}")

block1 = fileType.read(0)
print(f"block1.getRecord(0)={block1.getRecord(0)}")

block2 = fileType.read(1)
print(f"block2.getRecord(2)={block2.getRecord(2)}")

block3 = fileType.read(2)
print(f"block3.getRecord(1)={block3.getRecord(1)}")

os.remove(filename)
# Out:
# V1
# V2
# V3
#
# V4
# V5
# V6
#
# V7
# V8
#
# blocks:3
# block1.getRecord(0)=value:V1, bytes occupied:3 , capacity:4
# block2.getRecord(2)=value:V6, bytes occupied:3 , capacity:4
# block3.getRecord(1)=value:V8, bytes occupied:3 , capacity:4

# %%
import os
import math
class SortedFile(HeapFile):

  def add(self, key):
    start = 0
    end = self.blocks - 1
    block_id = 0
    rec_id = 0

    while start <= end:
        print(f"Start: {start}, End: {end}")

        middle_block_id = self.__filePartition(start, end)

        middle_block = self.read(middle_block_id)

        position = 0
        if middle_block.size() == 0:
            block_id = middle_block_id
            rec_id = 0
            break
        else:
            position = self.__findPosition(middle_block,key)
            print(f"Position: {position}")

            if position == middle_block.capacity: 
                print(f"position == middle_block.capacity")
                if start < end:                
                    start = middle_block_id + 1
                    #end = self.blocks - 1
               
                else: 
                    # I am at the end and need to create a new block
                    block_id = self.blocks
                    rec_id = 0
                    break

            elif position == 0:
                print(f"position == 0")
                # I am at the start and need to insert and shift
                if middle_block_id == 0:
                    block_id = 0
                    rec_id = 0
                    break
                elif start < end:                 
                    if middle_block.isFull():
                        #start = 0
                        end = middle_block_id - 1
                        #continue
                    else:
                        block_id = middle_block_id
                        rec_id = position
                        break
                else:
                    print(f"I AM AT THE START:")
                    block_id = middle_block_id
                    rec_id = position
                    break
               
                
            else:
                rec_id = position
                block_id = middle_block_id
                break
            #print(f"Position: {position}, Rec ID: {rec_id}")

    #print(f"Key: {key}, Block ID: {block_id}, Record ID: {rec_id}")

    if block_id == self.blocks:
        self.blocks+=1
        block = Block(self.block_size, self.record_size)
        block.add(key)
        self.write(self.blocks-1, block)
    else:
        block = self.read(block_id)

        if block.isFull():
            self.__addAndShift(key, rec_id, block_id)
        else:
            block.addIndex(rec_id, key)
            self.write(block_id, block)   

  def remove(self, key):
    keySearchResult = self.search(key)

    if keySearchResult:
        blockId = keySearchResult[0]
        recIndex = keySearchResult[1]
        
        blockToRemoveFrom = blockId
        indexToBeRemoved = recIndex

        removedElement = (blockId, recIndex)        

        #block = self.read(blockId)
        #block.removeIndex(recIndex)
        #self.write(blockId, block)

        # print(f"Current Block ID: {blockId}, Total Blocks: {self.blocks}")
        if blockId < self.blocks:
            # print(f"Current Block ID: {blockId}, Total Blocks: {self.blocks}")
            # nextBlockId = blockId + 1

            #if nextBlockId < self.blocks:
            #    nextBlock  = self.read(nextBlockId)
                # print(f"Next Block ID: {nextBlockId}")
            blockIndex = 0
            for blockIndex in range(blockId, self.blocks):
                block = self.read(blockIndex)
                hasNextBlock = False
                
                if blockIndex < self.blocks - 1:
                    hasNextBlock = True
                    nextBlockId = blockIndex + 1
                    nextBlock = self.read(nextBlockId)
                
                                   
                if  blockIndex == blockToRemoveFrom:                        
                    block.removeIndex(indexToBeRemoved)
                    self.write(blockIndex, block)                      
                        
                if hasNextBlock:
                    nextBlockFirstRecord = nextBlock.removeIndex(0)
                    self.write(nextBlockId, nextBlock)
                    
                    block.add(nextBlockFirstRecord.read())
                    self.write(blockIndex, block)
                #else:
                 #   nextRecordInBlock = block.removeIndex(index + 1)
                 #   block.addIndex(index, nextRecordInBlock.read())
                 #   self.write(blockIndex, block)
                #recIndex = 0
                #nextBlockId += 1

                #if nextBlockId < self.blocks:
                #    nextBlock = self.read(nextBlockId)
           # blockIndex -= 1
            
            if blockIndex != self.blocks:
                lastBlock = self.read(blockIndex)
                if lastBlock.size() == 0:
                    self.blocks -= 1
                


        return removedElement
    else:
        raise ValueError(f"Key not found")


  def search(self, key):
    start = 0
    end = self.blocks - 1
    block_id = 0
    rec_id = None

    while start <= end:
        #print(f"Start: {start}, End: {end}")
        block_id = self.__filePartition(start, end)

        middle_block = self.read(block_id)

        #print(f"Block ID: {block_id}")
        if middle_block.size() == 0:
            return False
        else:
            rec_id = self.__searchInBlock(middle_block, key)
            if rec_id != -1:
                return block_id, rec_id
            elif key > middle_block.getRecord(middle_block.size() - 1).read():
                start = block_id + 1
                end = self.blocks - 1
                #print(f"Start BIGGER: {start}, End: {end}")
            elif key < middle_block.getRecord(0).read():
                start = 0
                end = block_id - 1
                #print(f"Start SMALLER: {start}, End: {end}")  
            else:
                break
        #print(f"Start: {start}, End: {end}") 

    if rec_id != -1:
        return block_id, rec_id
    else:
        return False

  def __searchInBlock(self,block, key):
    #print(f"Block Size: {block.size()}")
    start = 0
    end = block.size() - 1
    block_id = 0
    rec_id = 0

    while start <= end:
        middle_id = (start + end) // 2
        middleRecord = block.getRecord(middle_id)

        middleKey = middleRecord.read()

        #print(f"Middle Key: {middleKey}, Key: {key}")
        if middleKey == key:
            #print("middleKey == key")
            return middle_id
        elif key < middleKey:
            end = middle_id - 1
        else:
            start = middle_id + 1

    return -1


  def rangeSearch(self, keyA, keyB):
    #print('Sorted Range Search ')
    keyASearchResult = self.search(keyA)
    keyBSearchResult = self.search(keyB)

    result = []
    if keyASearchResult == False or keyBSearchResult == False:
        return []
    else:
        for i in range(keyASearchResult[0], keyBSearchResult[0] + 1 ):
            result += self.read(i).rangeSearch(keyA, keyB)
        return result

  def __filePartition(self, start, end):
    return (start + end) // 2   

  def __findPosition(self, block, key):
    # print(f"Block Capacity:{block.capacity}")
    position = 0
    for index in range(block.size()):
        if key >= block.getRecord(index).read():
            position = index + 1
            # print(f"Key: {key}, Position: {position}")

    #if position == block.capacity:
    #    position -= 1
    return position


  def __addAndShift(self, key, position, block_id):    
    block = self.read(block_id)
    #print(f"__addAndShift, Key: {key}, Position: {position}, Block ID: {block_id}, Block Capacity: {block.capacity}")

    lastRecord = block.getRecord(block.capacity - 1)
    firstRecord = block.getRecord(0)

    #print(f"__addAndShift, Key: {key}, Last Key: {lastRecord.read()}, Position: {position}")
    lastKey = lastRecord.read()
    firstKey = firstRecord.read()

    if key >= lastKey:                
        self.__shift(key, block_id + 1)
    else:
        lastRecord = block.removeLast()
        block.addIndex(position, key)
        self.write(block_id, block)
        self.__shift(lastKey, block_id + 1) 


  def __shift(self, key,block_id):
    #print(f"__shift, Key: {key}, Block ID: {block_id}, Blocks: {self.blocks}")
    block = None

    if block_id == self.blocks:
        self.blocks += 1
        block = Block(self.block_size, self.record_size)
    else:
        #print(f"Reading Block: {block_id}")
        block = self.read(block_id)

    currentBlockId = block_id
    lastRecord = None
    currentKey = key

    if not block.isFull():
        block.addIndex(0, currentKey)
        self.write(block_id, block)
    else:    
        while block.isFull():
            #print('Block is Full')
            lastRecord = block.removeLast()


            block.addIndex(0,currentKey)
            self.write(currentBlockId, block)
            currentKey = lastRecord.read()        


            currentBlockId += 1

            if currentBlockId == self.blocks:
                self.blocks += 1
                block = Block(self.block_size, self.record_size)

                block.addIndex(0, currentKey)
                self.write(currentBlockId, block)
            else:
                block = self.read(currentBlockId)

                if not block.isFull():
                    block.addIndex(0,currentKey)
                    self.write(currentBlockId, block)
                    break

  def __unshift(self, block, rec_id):
    pass

# %%
filename  = "sortedfile.bin"
fileType = SortedFile(filename, 16, 4)

dir(fileType)
fileType.add("V05")
fileType.add("V06")
fileType.add("V21")


fileType.add("V10")
fileType.add("V12")
fileType.add("V11")


fileType.add("V07")
fileType.add("V01")
fileType.add("V02")


fileType.add("V08")
fileType.add("V03")
fileType.add("V09")


fileType.add("V00")
fileType.add("V10")
fileType.add("V12")


fileType.add("V11")
fileType.add("V13")

fileType.scan()


print(f"Searcing V13: {fileType.search('V13')}")

print(f"Searcing V03: {fileType.search('V03')}")

#print(f"Searcing V05: {fileType.search('V05')}")

print(f"Searcing V90: {fileType.search('V90')}")

print(f"Searcing A90: {fileType.search('A90')}")

print(f"Range Search: {fileType.rangeSearch('V02','V09')}")
dir(fileType)
print(f"Removing V06: {fileType.remove('V06')}")
print(f"Removing V13: {fileType.remove('V13')}")

fileType.scan()
print(f"Total Blocks: {fileType.blocks}")
os.remove(filename)
# Out:
# Start: 0, End: 0
# Start: 0, End: 0
# Position: 1
# Start: 0, End: 0
# Position: 2
# Start: 0, End: 0
# Position: 2
# Start: 0, End: 1
# Position: 3
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 0
# position == 0
# I AM AT THE START:
# Start: 0, End: 1
# Position: 3
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 0
# position == 0
# I AM AT THE START:
# Start: 0, End: 1
# Position: 2
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 1
# Start: 0, End: 2
# Position: 2
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 2
# Start: 0, End: 3
# Position: 3
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 1
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 0
# position == 0
# Start: 0, End: 4
# Position: 3
# position == middle_block.capacity
# Start: 3, End: 4
# Position: 1
# Start: 0, End: 4
# Position: 3
# position == middle_block.capacity
# Start: 3, End: 4
# Position: 3
# position == middle_block.capacity
# Start: 4, End: 4
# Position: 1
# Start: 0, End: 4
# Position: 3
# position == middle_block.capacity
# Start: 3, End: 4
# Position: 3
# position == middle_block.capacity
# Start: 4, End: 4
# Position: 0
# position == 0
# I AM AT THE START:
# Start: 0, End: 5
# Position: 3
# position == middle_block.capacity
# Start: 3, End: 5
# Position: 3
# position == middle_block.capacity
# Start: 5, End: 5
# Position: 0
# position == 0
# I AM AT THE START:
# V00
# V01
# V02
#
# V03
# V05
# V06
#
# V07
# V08
# V09
#
# V10
# V10
# V11
#
# V11
# V12
# V12
#
# V13
# V21
#
# Searcing V13: (5, 0)
# Searcing V03: (1, 0)
# Searcing V90: False
# Searcing A90: False
# Range Search: ['V02', 'V03', 'V05', 'V06', 'V07', 'V08']
# Removing V06: (1, 2)
# Removing V13: (4, 2)
# V00
# V01
# V02
#
# V03
# V05
# V07
#
# V08
# V09
# V10
#
# V10
# V11
# V11
#
# V12
# V12
# V21
#
# Total Blocks: 5

# %%
#Create files
import time
import string
import random
import math

PAGE_SIZE   = 4096
RECORD_SIZE = 128

def creationTime(FileType, size):
  random.seed(size)

  filename = f"{FileType.__name__}_{PAGE_SIZE}P_{RECORD_SIZE}R_{size}L.bin"
  if(os.path.exists(filename)):
    os.remove(filename)

  start = time.time()
  S = FileType(filename, PAGE_SIZE, RECORD_SIZE)
  for i in range(size):
    T  = "".join( [random.choice(string.ascii_lowercase) for i in range(random.randint(1, RECORD_SIZE-10))])
    print(f"T: {T}, i: {i}")
    S.add(T)

  end = time.time()
  return end - start


#defines the file organization types
fileStructures = [HeapFile, SortedFile]

records = [100,200,300,400,500]

mapSizeToTime = dict()
for i in range(len(records)):
  #map list size to algorithm average time
  for fileType in fileStructures:
    print(f"Creating {fileType.__name__} {i+1} with {records[i]} records...")
    mapSizeToTime[f"{fileType.__name__ }##{records[i]}"] = creationTime(fileType, records[i])
  print("")

print(f"Finish.")
# Out:
# Creating HeapFile 1 with 100 records...
# T: ooyfwmxlnqzdrdcxoib, i: 0
# T: ugkhjygfegllungmorizmfuudfatmeysfgfavhozumetrybthwtyqwjwskqvkrlpmybdjunihwwnyqzpsiebv, i: 1
# T: kfbyiwwdwbzthjqtguzxxslkoawdpgqdxtgbmxdmvwetvuprbwofbzpybghfdbegucdicwxmbrn, i: 2
# T: okwoqgtsinegnctimiwdghbmiaizjbarjhmauchjuuxuacslkvobxyfcawtlz, i: 3
# T: efwavxawkqmfmmxoggftsricuouxenssqdujedsthbmzonwlccbonasepdwcjuvdrseeyrs, i: 4
# T: flxsmwxdupkdvzpjhxy, i: 5
# T: lhbahqdrcepubxplqpgpbvqsiatqqydwfbswhowadhlkdujdjjwotgkcfktyutegwnccktgkievdoyagqfpxtvbrolacpbnmegnf, i: 6
# T: iigjmmikaxihqfbvncxldfztplg, i: 7
# T: vqhmaokbiptbzclbuiysostxjrmlkfexfkpymtnhypxdqgfchcatziphknwbtiplwkwwcqjtxfljhmnbaicrxywdziunprixyurv, i: 8
# T: bpvujfccyptuugqcktwemqbmknfzsnhzvxtvcolajnaowtjzgzopuwqepegujmaamdyuzxsheyyhpfnjjqmmmswyvpdrsyebqxbaqnmmhadchvmi, i: 9
# Start: 0, End: 1
# Position: 2
# T: hlumjizkyfxitsdjjslmwxjvcxupmjtenytmncgogj, i: 34
# Start: 0, End: 1
# Position: 10
# T: ck, i: 35
# Start: 0, End: 1
# Position: 3
# T: hfjocjlobyyuvceljgznmkbdreeqfwcuskckbfgjtpbwpvufqdsetpddvacbilobfduqreqrxbpejjnukmptfjbor, i: 36
# Start: 0, End: 1
# Position: 11
# T: mswvhwvfbapxxruiynsqxvqvchcetuxivurrwzdgeazdtuapqjzgdpotqpkxstgrcvgtyegibulquojlforzudwwazmiyavyzojfoxzodyclzakucs, i: 37
# Start: 0, End: 1
# Position: 19
# T: pbuqbmthermrmoyajbyykkoawzebncklqtdxobtznpspinddquhqxzankoqmawesyyphehhcwrurlrgunatovzheitkqgmdcwttujlghe, i: 38
# Start: 0, End: 1
# Position: 25
# T: neoobbwgtbzejwivoxepkuvprliyiyikfzblieehsotldlgtpmeuubeugbennqslimgzvtytkhgqzhvxnskrpitzcol, i: 39
# Start: 0, End: 1
# Position: 20
# T: sgvzsqsktubizwxsnsgjizamhiioilknkowpxossmdrxwdauignrvhfkfquwbpggteatqtmndp, i: 40
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 0
# position == 0
# I AM AT THE START:
# T: hpmzryvltqxezoujuvj, i: 41
# Start: 0, End: 1
# Position: 14
# T: nhysnmfruspgxoykhgkrioladfxijqhqablpsisgdrvhxzdifeqyaeyshhwvlw, i: 42
# Start: 0, End: 1
# Position: 22
# T: qermaysqesxtpazprytfhwhxjfhyjfkeyz, i: 43
# Start: 0, End: 1
# Position: 30
# T: buirltsqoupuyxzwtssevkiuvekjwdiuaehwhapnhdiyoukyoknribdybxayfkltqxbbbfasytvtmwq, i: 44
# Start: 0, End: 1
# Position: 3
# T: dfiugtyxjboiakieqwdlzikbuwlovpvb, i: 45
# Start: 0, End: 1
# Position: 7
# T: mdvulphrgqzmairtskxertonsggyhbpodvtmomizxybgghjdohcjvfciopzhdc, i: 46
# Start: 0, End: 1
# Position: 22
# T: yuucwzzgatuotcanhufwwrniukdaeudmxxpxdyzhghrpoyfkeyz, i: 47
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 15
# T: ddawvstywtxgdsligrxxpactbhugjmxqkvdnsvjurokiuxdobxkxhwafxdrjiaegefyjulkelldldunklmdmbqckotsmpcwtphoknfuuuqgxtvbw, i: 48
# Start: 0, End: 1
# Position: 7
# T: qmldkzzdkrrtrluqqaimpntflhtrxowqzhnuflkjfbtnarchfavmoqroyjokuhywkdkslkmazwbmpkdvbvrlkfiqcssmqtexffzvevqjsmdmiiyobbhdic, i: 49
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 5
# T: wwaugbwozfny, i: 50
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 17
# T: isoimplbqtjtqidpxyemmxybwelgbeqeybqi, i: 51
# Start: 0, End: 1
# Position: 20
# T: xthviisujilublwcckwyehdmvfybkisyzkuoiqoluzenlpwrpjy, i: 52
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 19
# T: hixptbdplkn, i: 53
# Start: 0, End: 1
# Position: 15
# T: tpzvbrqtcxuywmpquaakttdljehxxtdkrhvrpmpljfvzjymtgczhnyaukesblojhpouyaovszwildivixrbgteapeopqwddjejbhgenhcjgj, i: 54
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 13
# T: cwivwrivhjwcwehkzvmnmzklguzwzzuhqncptumuohrxvyudobatumj, i: 55
# Start: 0, End: 1
# Position: 6
# T: dwjpbwdugljcopodofopzmtkhogrgudukgbcdrcpvplpirelwxqqiapheefqpvxkekfmqmiretmdnfxbdfriw, i: 56
# Start: 0, End: 1
# Position: 10
# T: xrbo, i: 57
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 23
# T: cgzsouwpnyoyifbrqhepa, i: 58
# Start: 0, End: 1
# Position: 4
# T: anjiukrq, i: 59
# Start: 0, End: 1
# Position: 0
# position == 0
# T: fmlopbsoucgdykfjbcdxyyyuipmkiwkrlxc, i: 60
# Start: 0, End: 1
# Position: 15
# T: bxiyazuyylkxeqvbvvhyehcsataeum, i: 61
# Start: 0, End: 1
# Position: 5
# T: xemipocestssvejgoxruwdlvzehjkudyzxbltzupmejolbhuhdmgcmclybllkuplhrgwkqubeaizpesgkldhjioawrqbpdomrlkgfnnyigwjxob, i: 62
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 27
# T: kbqrsggfwfxtmuvenhelzkcvfntngxmkdtwveejecggkvzvxcxjgrqkjojjirrtk, i: 63
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 28
# T: fzfiobaozl, i: 64
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 19
# T: zehxcgmfwuvzrskkeeljpmiyfsnhkvatubahf, i: 65
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 2
# T: iushmgunliijimeigelgortmezmptwiyzmhgbagjpbyrgmdyedzdqt, i: 66
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 29
# T: wfptgcozusgucmyklrwkiueftchgjquootzugfevpnqblgpukwglzhdwqewnrkommbinmuumxijjmvmvsbueydctzdhdzfxpxa, i: 67
# Start: 0, End: 2
# Position: 29
# T: lvfkllhnahdbyhjiidpnytltcqfmljwywnsihvhenpolzcqvgltupdkxkfvgjbjwuzxttpvhkteuobbavktoawuxywfemfiauucdywgaqm, i: 68
# Start: 0, End: 2
# Position: 3
# T: hcusutuftqeiqlsimrjkppfpiztwevztrgpefihmccoftpadzxywjdjkpyyhjbuloeqlpfnouykuzudsgyvmblxpgirtbxuwyk, i: 69
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 21
# T: ffztemxftruzonzxikvwyyxyvmdkkxruqkjfxkproowovejwbvwohshnixppzuytwkgacjxakeuzvsbkftedfrgnonsyzzylvbvkipidcbuvupvi, i: 70
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 15
# T: zpboijnwvyntvookiztsdspqumllvjjqwdqehoxrueoqjekwqfwahdxzzfgrjhjddnvlbyvbtbtstmrcfcnwzt, i: 71
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 8
# T: fjbantszdaexqvoocdvaczsknnnlbtqcuphmgyyqbqfaivtymkrgphszlghydmiauozlejgpcdoquozijdcvmjphlbjupgahxccvlk, i: 72
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 16
# T: vjanbnwufc, i: 73
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 1
# T: kbpbohbwdpvlwuibeakkmvizglvsmqsusukpohtcnlckngbqgvlroneutubgvrpigtyadgubxxegiibpvozrzaxdjgdbbr, i: 74
# Start: 0, End: 2
# Position: 2
# T: xbzexcvmzahbqjsrjycosrelscpkkrxpvwsqipitwrxd, i: 75
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: lgvpdgsailoeidlhpmcdmkwrimkdmidsesxhexxwvzlfhzkzecgelhcjfgewtvvlfsftdripnnkriktlxcllndwfeggjqfm, i: 76
# Start: 0, End: 2
# Position: 6
# T: icasbpevsclvtgofuwbtmhjbiyjxhfamvvpyimatdmszakcgzathkqznahnogutngrxcequnurgovxsamgwrqyjhmbvlprdcryrvgoupogburqg, i: 77
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 29
# T: refrlfiljlnbpxyafxpzocul, i: 78
# Start: 0, End: 2
# Position: 26
# T: zorfkr, i: 79
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 15
# T: qvoojxaznftzrmwaunfsrrfmxspwbaoasgqgzkx, i: 80
# Start: 0, End: 2
# Position: 24
# T: yocjbfaffnbyfpptmqngjntnkwfstywlwxiitgrcelprgmyhzujdzzjcdaftcdadgvdevpguqnwonfmjjinzadjbvpq, i: 81
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 14
# T: jzelgnjmalixwwlotvfwjufflwlxcamirtiprqxhmzwnmxnhrclxkmgpiwfb, i: 82
# Start: 0, End: 2
# Position: 3
# T: nrugesbftirfnipdqnddxhzpmdrzormkrcafpafmnoqjhgvnvpjhvlzoxfirrangnlhxtguujf, i: 83
# Start: 0, End: 2
# Position: 16
# T: hzhqkrmbvavuwtkrutasgeqkeicrfovwv, i: 84
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 29
# T: zdtqvsohg, i: 85
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 19
# T: ulmwsnfpfvqyvfktpjp, i: 86
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 7
# T: cjrwbayufftnlyetbiahqvxvrpqejqowskwqsf, i: 87
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 7
# T: otemuqyep, i: 88
# Start: 0, End: 2
# Position: 23
# T: hsqyxhmlnjlrzfqkwhmzvvddzthukfefpyvbueilnqsgwxvxflsuwygdfdvlnjkbrbmigimevggaoxjtbxszdarmukbzixavzgyubhymrbjp, i: 89
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 30
# T: jhllmlcajpyevwvmicjc, i: 90
# Start: 0, End: 2
# Position: 6
# T: wtbpbhepnpyehidtqtddpsfzonhuajwabzyyvhngnpnkirgkmzkvxprkznzoonstfmdhwckeilisqffg, i: 91
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 17
# T: zziqhagklhupezsnnedtqdjcjhehhqjkinwkdxlzcjidcqfeqxrmbpuidnlsuyrjzilztxrextbfmrzdbgcaf, i: 92
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 30
# T: ttwsadkiyruojsaxiwsgopaocpepyogbrbcwjbtq, i: 93
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 8
# T: sfuajtkudxcuopwfgenpsdolpjrvnsmjxuvxgspjsrtklqboxmayxiiprpfjdtujexgspslucdgolnnhueotyahydfb, i: 94
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 4
# T: duumnipbtvmwahsjr, i: 95
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 14
# T: qembmroizorackjjqgtajvrebwkoosit, i: 96
# Start: 0, End: 3
# Position: 29
# T: aqynsccftcnahpzjtxryjuroywtlmik, i: 97
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 1
# T: imjzenlpwpdpjvvahkyzrdgjqgtjfixudicukbcixxrwelugfakejxtisvrnvdldpkxfjsbgudcxlazhdxcwqtpxzggnqqpijk, i: 98
# Start: 0, End: 3
# Position: 6
# T: cwoq, i: 99
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 12
#
# Creating HeapFile 2 with 200 records...
# T: gxwaet, i: 0
# T: ziawowfwaoioohgudjwwmludonhvpjuwdxeeppfgmpdshrvuzkzderuhuxbswlzfposvjjgdgwkirzlciwqlqaeqgjwvcaokdjlayiulidhaqrv, i: 1
# T: ngpphbgqocyujxmbaazjtzbiezeoazwofanihosqtqgezadoobxudxawwcgqvwdnpbduhuqxhwyfncovhxwxlnfmuqabbxy, i: 2
# T: ozvywbbhpenwvbfzemmzxaesplpdfoendbqmezswwmrfbrwmwoelknzqsohyopnzrlfk, i: 3
# Position: 23
# T: dsmqncviozbafgusyiehsdtgbsrqhmiytmlcokafpt, i: 33
# Start: 0, End: 1
# Position: 5
# T: ltrpkkbkbhgcxfdxzxlcofjey, i: 34
# Start: 0, End: 1
# Position: 17
# T: nmscqifnyyhbfrnzsxneneazncdehhp, i: 35
# Start: 0, End: 1
# Position: 20
# T: gehncmbhidcyaabqykvsvnwflgveeopsehkjrhgxnwdxftpekjjvpjvzlwhbqnlynzkdqygujwierdgbblhhtyqlydxfesgqesxzehg, i: 36
# Start: 0, End: 1
# Position: 7
# T: kjnnfuljupdlejsatxfijgywzwqduxdmsdalytxtbziivxuthhqjkdurxagvsasrlhwmedeqecblwxwohieaolbrmbupmrazqfyjnnrndfwvftibpij, i: 37
# Start: 0, End: 1
# Position: 15
# T: lziikbunscbdoxsyctibttocxxkeowaxskenmpieuxdkelnzxrntdzjwtsjufbyslldvlezgdxnttuwkabznaxkzzdhfdiftujequmkjqrkjtnbldio, i: 38
# Start: 0, End: 1
# Position: 20
# T: mqcgerbatspayngxhzoitselalwjiyhgbkwflgyfhwsqrzzxvbftsjuwvdkkxwedruylhmeceegyhvjfxcorkuhxmyd, i: 39
# Start: 0, End: 1
# Position: 22
# T: lfffbtaznjlexaoohaxlpdhaiwbulntqirxvobrqakcvexqfdtumhcvba, i: 40
# Start: 0, End: 1
# Position: 19
# T: zndeqajbzjcjciauickprvfpqjlzzmyjqsedbcgpfdwjtdntnkyzujdhfjwyuwoswuelbdmq, i: 41
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 8
# T: upumikmwrnhkvkvrldexnwbozzfshhezbnehprsrguunfrmkrkrumpvzfqsztmgbznagvxqzkhyvinjabh, i: 42
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 3
# T: ekvedkjgzomvnphssdbgddurjstklfaqsesgobclvhcxctqmbitfdhhbpyfjteeivnwdslqjeqnyccrbrnfzf, i: 43
# Start: 0, End: 1
# Position: 6
# T: sqibovgtpqbejutmobroxxlbmivemuyczjqkpjaalhyhmcmclfhfvryxfwobqtnailwwxhpgcnetnngbzcovxpblxhspkiuhharotwqdkxetqvnlk, i: 44
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 1
# T: cgxcmoxzkhvabuqxhdbfwtv, i: 45
# Start: 0, End: 1
# Position: 3
# T: rgybulbssnsbcyeeqyqcqovaszgyvqgwhkx, i: 46
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 1
# T: hauuihnuetjwjktpzjwlngpwedrpcoclynepomypqzdywgntwwlaiejjkbpubrnujpnmqyklzikucjiwcuyelwutnfdsfstymiu, i: 47
# Start: 0, End: 1
# Position: 12
# T: qrxyuzuwfaomcjowizwycfslzyhyiswomjylibzizpdfmajhjkyianjalugiihllnlttexkbnqvczezcjtqrdltllvgvy, i: 48
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 2
# T: tsgclbppafrobnhmlceyonxpbyqrbxikjoorawkcgoaakaieqcoyhdmjclaoelfpbflxasornqrzvynzpdcvvnulumpgrinotymgrw, i: 49
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 8
# T: mbdrdugnzczhodtedapnvlhdjrhnszfxrufd, i: 50
# Start: 0, End: 1
# Position: 25
# T: nxsjappootvidapdvcnkbbdxlgtocqcduqrtaclzpky, i: 51
# Start: 0, End: 1
# Position: 30
# T: qicnpmtsm, i: 52
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 4
# T: qxwazamhpolvjsqqrpumxrdwlowaztomqoghgosffhyelsvhaofqhoiewjqzcxmssczczkrpntlajwqqwfmlkgppkimofk, i: 53
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 6
# T: aghwgdyo, i: 54
# Start: 0, End: 1
# Position: 0
# position == 0
# T: vsoxadvlthzwkllxxlgezqjvgplfesljsjwmnzlhp, i: 55
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 18
# T: tpfnfsuqkuew, i: 56
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 13
# T: royfthkqytsicrhjbrt, i: 57
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 9
# T: rifhsdzmbyuyrdobcrwtoyefzwuvleuxhycwdllhpqosduleuzr, i: 58
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 9
# T: esdqxcxvohmhiganneiwvyrzqmtpqvacaqcdmslcqx, i: 59
# Start: 0, End: 1
# Position: 9
# T: ifycowdlcenwilmuvlpzxtuudhgozqqgophlzwxrhxtfmjsbhul, i: 60
# Start: 0, End: 1
# Position: 15
# T: srpbwmoqm, i: 61
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 15
# T: retbucbyydvokmwtoklmmpgjkdeckghnyofyunmenbdxszwudshfertdmhnzxizvjx, i: 62
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 10
# T: kn, i: 63
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 22
# T: pmwktcnoirucewcciswwzwsut, i: 64
# Start: 0, End: 2
# Position: 7
# T: gecxrn, i: 65
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 11
# T: kbavqhfrduqgvzoaxhivmquqydup, i: 66
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 21
# T: vjuijqxkfimejpqdfnugehw, i: 67
# Start: 0, End: 2
# Position: 28
# T: q, i: 68
# Start: 0, End: 2
# Position: 10
# T: xxhxlqgpbjenuvkalqaivsvkuagxfjvkgcamjatudrvojbqahws, i: 69
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 3
# T: ltgxltoaesrohdnkhnzeqtsczjlmlxgvrwxruptkrzjeiaoymawhybvv, i: 70
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 29
# T: vdgqixvrtsbwdnqsysosxbrpdspsxdfjwnxyojshrbqsqhfwuzyfyu, i: 71
# Start: 0, End: 2
# Position: 30
# T: mjnknosc, i: 72
# Start: 0, End: 2
# Position: 3
# T: dbvtjsdkwkrrkahnmattuqvxtnmkrjeezwzxeiybcvmibqsedacgtmclyivihi, i: 73
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 6
# T: obktdeldgwtktbkaojdtsruplotczmcasqpsxlllhbnwegsickaegirgwpuxnrpvgijwwluruquqfswfnokb, i: 74
# Start: 0, End: 2
# Position: 9
# T: zjvchpdzml, i: 75
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 10
# T: bdzksueaciocdvcqdsqcqgjguldyjqchhripctewmcnhyppstbhmlptelndbxpgvemsyskkszcujzairvwcslnrypypviwrjvzmqbspaegscz, i: 76
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 2
# T: efzjpbreb, i: 77
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 10
# T: jdhiqdgfoaembsg, i: 78
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 21
# T: nxlbfsncybgjhjknatlcydhiotmvb, i: 79
# Start: 0, End: 2
# Position: 11
# T: ijbxbtnumcuwinhygalrvddbxmprg, i: 80
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 20
# T: khu, i: 81
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 28
# T: dwnwflqwhjyidxonhepljhpuxpfgduvdbkwexjzssmqwabpqscjgeeszlkbopfxuoqiddojsmvtnrtorynswvwxjvwitiy, i: 82
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 10
# T: ttzyuphndzatqtazdfqvhewnlfvndnscxzgndxyyxhaflpllroiwinmquoabvocjtjupkeuutbnadlouykzwbvzwbyelrvkssfyyv, i: 83
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: yildkjmmudmejysvfunbzpjxsixerbufvsrpyxwrxz, i: 84
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 17
# T: mndnlomidcjeyddguvbjjjabscthdgbdsivhyocwphsyxkxwqbvurnmxmuwacrkrbygxz, i: 85
# Start: 0, End: 2
# Position: 11
# T: gbtnxdrvatslvqjqewflhyghehonsdoonguloipsttahghojclloyiitwphirnlnuucjasjxzhr, i: 86
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 15
# T: tmatbesmjjtzjophrthrlbblxvuujdjwnhaycupvqqcjzrdfskpesgjvbzhvbtiohflfjrijlxjlhfvyqdfyfwhauobvrjuco, i: 87
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: yztkytuzurpacs, i: 88
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 21
# T: vxinxmmzeowiwbejvvffhgeaeahrhlzugppfkomobpkpsjsnrpapdluyfysqpjwxaniluuitzljcunmuzyzzhvvqhthonkytublglcz, i: 89
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 17
# T: tkq, i: 90
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: hvxfibqnuysbmnn, i: 91
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 21
# T: ztfpmpitixznjcldblvibooqvvmabcjfjxmyxxjztynrsgonoawkgjayzohwlrvuwdfkopaopfgkptzxwdvvjwuoxusdjqxhgdh, i: 92
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 28
# T: teeujtihzfxpbtirplxmecdoyztiuwlyynjieuprpvzo, i: 93
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: aarkczpgvldroseqlnttnduggjvamjkkramnpxyiidvlphjjenwyjtrolpjk, i: 94
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 0
# position == 0
# T: nqilkrrodvvmlpyrsskxxsbufilkjwnczeftrwslsmrmasqugqxtvszgxbvwimejvtmibhefpaoznoadluzan, i: 95
# Start: 0, End: 3
# Position: 18
# T: izvtwhlrnerqvpqfukuttgoyhppqrepjucpslvxvbbeyxhitwmbqwtkpraqjrinptxb, i: 96
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 26
# T: xumneaagrpzxrqppiozltunigrkfhzimetgpqhverhldchqelmixsctlxxmzvapidciejsijzhj, i: 97
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 26
# T: dcbblivgmiczbyfhmfsaxrcmoeajeycmtstytjdhrxyurkaqlhenipejshqlifqetwbunwxyywvjx, i: 98
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 9
# T: hjaqsuispsnicehxmbxkeoomeuzrdcmkejmpimtukyinzzlrayysiwglbcxfhjdyyrwihhmvboplqruhrwiheaqlucziokiszafbhuzd, i: 99
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 23
# T: vfrmztziscnmjawlnyfjggremmkqqjeizehmswekztytcgpmnvcjnfewlmm, i: 100
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 22
# T: nqatuidksbshyhhyuokplluryumaxwebxuhcymapzaakmjoiosxozeqxggzhsfxqlspdhnyzbibsdwwtuualomcgyfregwwwetxya, i: 101
# Start: 0, End: 3
# Position: 21
# T: hlqzjenoiswifaabshpbotgegxduyvkcfvhntwvdmmteoqetyfyejnuyol, i: 102
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 24
# T: yxwqbarkgnkqdfrrmoqhjaoarbuntljkhqrmaakjaubrzojw, i: 103
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 3, End: 3
# Position: 3
# T: bewupzjd, i: 104
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 4
# T: ohvajvsbzcsxetvcpfobuagamvqprvxcxrajqzqcygckxqdcfozmdaooessqjdlolvjxlbkjswoncdwquzyacpgrg, i: 105
# Start: 0, End: 3
# Position: 29
# T: voddwextoqkrkfgehnfepkjepekzl, i: 106
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 29
# T: xojxiohaiwasszvgtmcsbdtxqdefoumpqesbeexxvohaznqqstmxwhykejbyjbtkcbeo, i: 107
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 3, End: 3
# Position: 3
# T: otxix, i: 108
# Start: 0, End: 3
# Position: 30
# T: kmrkuvnnevdgyskdjskkalccfgkqshsrmycowfldvbpmhqudtjjgbevyrjboixqsuvlrlgelrsvuaghyggtdibnstzkwgxtl, i: 109
# Start: 0, End: 3
# Position: 8
# T: mahyyd, i: 110
# Start: 0, End: 3
# Position: 17
# T: okcxnacxgtwetzphktacgnkewivbwzovobwuovnnkvbxwupxarreuschburjnexzzn, i: 111
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 1
# T: osxelzylpnnscmddcrfjltjbysrwquonrwsnaxbvjlscgk, i: 112
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 2
# T: rhzrqdxzgkheayjuycljfsrbpcivzoytxxratcryqwslmsczknnxldx, i: 113
# Start: 0, End: 3
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 3
# Position: 14
# T: efkcqtirexmvudchfqcmyvthlenqpynxtembsdsfrllldyhjfldocrunrjmdwbrxawkgokhvkjxwnhjutgcxffaclmfckwkwyak, i: 114
# Start: 0, End: 3
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 14
# T: uetqwprohiojcpqcfzhlagrqcynyyvwkossqnhebhhpbuczgiqzykopjtylwvgdmpuggpu, i: 115
# Start: 0, End: 3
# Position: 31
# ...
# Start: 13, End: 13
# Position: 24
# T: czduozzdyijxfadvumhaxkrrrzqhkynohgzvmwiyxtdxublavwkbazsgiyltknlpbmbrjrzuikmqmoupmbovjcfkjtjc, i: 430
# Start: 0, End: 13
# Position: 0
# position == 0
# Start: 0, End: 5
# Position: 0
# position == 0
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 16
# T: m, i: 431
# Start: 0, End: 13
# Position: 26
# T: bumxynqklvmhqykkzsotuarceywtukkxcakjavzfdvzudzjzjwrquewlngmllxeuyjvsmrhjcyebytcsiylzgfmzsxyspfoeowqkyjhjfdakhqc, i: 432
# Start: 0, End: 13
# Position: 0
# position == 0
# Start: 0, End: 5
# Position: 0
# position == 0
# Start: 0, End: 1
# Position: 31
# position == middle_block.capacity
# Start: 1, End: 1
# Position: 0
# position == 0
# I AM AT THE START:
# T: glbqglrhnvukcvlxeiapifjejibuexnjqhltquiuyppnu, i: 433
# Start: 0, End: 13
# Position: 0
# position == 0
# Start: 0, End: 5
# Position: 31
# position == middle_block.capacity
# Start: 3, End: 5
# Position: 0
# position == 0
# Start: 3, End: 3
# Position: 12
# T: aryqkaqecnrawdmrdpxygsmuqpcojroavuouhhsjnkoydoqyyyvlgecrcfya, i: 434
# Start: 0, End: 13
# Position: 0
# position == 0
# Start: 0, End: 5
# Position: 0
# position == 0
# Start: 0, End: 1
# Position: 15
# T: druuhvljldtboaxauqawtiywraoeekbnfwrxqmpduissyrikhmyazkqnnyqifhxtjtywrwizoiymfyptssuthxpwzzds, i: 435
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 1
# T: gprmbhkpyczcengmlkmt, i: 436
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 18
# T: eceazatllhinmijdsywqovufwnpdrahntclslejyiigaqs, i: 437
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 6
# T: pwarkepfkxehdemkpwloyxeufzpfvir, i: 438
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 6
# T: ginwbryurfnhoshwzuxbhjjvyrnmqvgxfssgtxegseskuywwswstaynwwmfegcawkatxcqmmbzpwtbovxwlzdawyfswlrsumhhbsvtoachk, i: 439
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 13
# T: wyqfwtniibrnridulvjtgqovpmtpqsoanmzntdjytnrweuoudclmqardcszbdfznigwmqfufzyyvyljndbtokmkgsq, i: 440
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 0
# position == 0
# Start: 12, End: 12
# Position: 25
# T: ttrvdglbjbmaubkqkbvkouqgsgcmwf, i: 441
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 31
# position == middle_block.capacity
# Start: 10, End: 10
# Position: 30
# T: gvticqxvjpefldkudqltoxemtvojyolingozwbtptgvhwenxdkoxdzmzrwirivqpnftlvpiqcsqgqqeqvjvpwinetkdmrwghnz, i: 442
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 30
# T: hykvdfxc, i: 443
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 16
# T: yuzqatrpuhugeqhxrezvetdrnfaayfqxmoynzljqezwfwqndpbdfixgkykoqzrhhyyqtnbwmpnu, i: 444
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 20
# T: ifzmcdwqwmkxqqfuessqzkdaldcsxsgejicnurjhwctpimchzcvyabgqoglfgdefkfdadsygknl, i: 445
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 21
# T: nndptuuwhzwqqsvstzeac, i: 446
# Start: 0, End: 14
# Position: 25
# T: peszrdmuizydcorbytyxskdnujkgptprkrqjanin, i: 447
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 0
# position == 0
# Start: 8, End: 8
# Position: 25
# T: ecotriqrsofxnpwcpswseqbnmiymqfeptlhbiyzyolimorzdotgrolxwriwietogenyzvaeuupxnxcux, i: 448
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 9
# T: xpazmngymulpcukxrahovuvajwtgmsghvdyivmiujuulxqdscgptoaacchzufyifuwnsblzg, i: 449
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 13
# T: twaymjmohxxqdzulfendqjmlnxcruwbwkimdcibucouulbawntrfkhcqzimrxaonbohmikty, i: 450
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 8
# T: agegtnbdrhfpkyqvpemnyqinopqgcpqhqrgeaupoliofarlgzwuwvrfowvxserpcvdhzwoxwo, i: 451
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 7
# T: stwgxhlhnemijihcursbmvyoswhdjgjnpkogaqecqiukjikzgowqaetyicglubwniqhhcjvfe, i: 452
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 31
# position == middle_block.capacity
# Start: 10, End: 10
# Position: 29
# T: uwzytqqjbfxamsmyqqvldxocmbuyzzeqonitosufwbgaiibcvihbyitkhtiuciybdqyolukqoczjrlbroppdozqdjds, i: 453
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 0
# position == 0
# Start: 12, End: 12
# Position: 2
# T: kkosllewasnkigtzeqmprpzxxptlpojlhaafvmohsyoxgrfwvopdennpdiwwxjnqkqdbykffpxvttuin, i: 454
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 30
# T: ymstnfpkhsixpsvwcdxdehgzvqauxjqheospacldapkzishrvwugxwfzzqdamcvniysipfxtmggmyhiabseawhtacvwdiuxvjjmhrimwevnhklgh, i: 455
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 28
# T: bxganaygrcfba, i: 456
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 3
# T: eqbkyotodhwraozjsqdmpldkumcfqzlstthsihakn, i: 457
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 16
# T: paewsgmwjjo, i: 458
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 0
# position == 0
# Start: 8, End: 8
# Position: 25
# T: jxjvjjsksbvuks, i: 459
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 29
# T: smucqjnxcnunpgbwbvqxeucxfyfixjfnpzmckfvnolmvgiaampjhmpfwuajbpr, i: 460
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 31
# position == middle_block.capacity
# Start: 10, End: 10
# Position: 28
# T: kzrguvrzelbocplrelqnsucqnvmfmgxyzmbdfsvkiotemlkbjzinxjahtaiiycyzeryidbfjiwafkevisauxdg, i: 461
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 6, End: 6
# Position: 17
# T: bctldxbiyvrxbawbnatmlsqadxqyctxkixyzwkjrjaiyeknazqyvixygywxgbzbwfrv, i: 462
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 18
# T: iypwxomkdgcoqwlzzbsxzpcsaphptkyvtewchnbgfvmgwxnzrtimhrpldbdnnpwwrlzqgxotcvndes, i: 463
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 13
# T: vnkupblzptyybdmzrfzxptaxzmkzbmkwlmkuqrmrwtdganln, i: 464
# Start: 0, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 14
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 14
# Position: 0
# position == 0
# Start: 12, End: 12
# Position: 25
# T: hwsclmljzwiikhxylqjtifmipnttqpnonjoghhjvyyptbmciahzgrufylqyfarorecczv, i: 465
# Start: 0, End: 14
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 20
# T: ixjvdwkuowfendfmzsggrwaipdaeilmznwameafpiazldtuhgelyqmiihkcwp, i: 466
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 13
# T: cmi, i: 467
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 12
# T: exqbwgdtgvyfxkjjwndxfu, i: 468
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 25
# T: gdsiymyjkoefurznmecfvbygozepvbwxcbibhgplwghxjhfxpxgmcmcdkcawzzymhoivibfffwjvhaxrnuplvpattrfllapuhyto, i: 469
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 17
# T: mskxobrnfrpamcgkv, i: 470
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 0
# position == 0
# Start: 8, End: 8
# Position: 0
# position == 0
# I AM AT THE START:
# T: zfcvbhepaxjxqrlkngdweqjwlmkcxrqydfmdnzdxrtzemhzryaxprjilzflsgneegzkrmteupmgijfjxbmzezryxndtautesjhgqatvqwtwsgdaenc, i: 471
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 14, End: 15
# Position: 20
# T: srnqdueaixae, i: 472
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 11
# T: qyhkgutifrhzeniqcdwooyjxniwyvdvhtoamftbpthxstrwzlmotiaapfhj, i: 473
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 31
# position == middle_block.capacity
# Start: 10, End: 10
# Position: 17
# T: ejwrjaztrcfpqgfrsldqebawertxthclftkgajllsvetknirbcuaaxsauopa, i: 474
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 17
# T: tocqopdxexwqfserijqqkhoue, i: 475
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 23
# T: viliaoyhfoqkbqxjonxewloebayebgollmsxfhwxumutkprimlzriizdxiarfnazcswuveovpndbiltcrwwonud, i: 476
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 15
# Position: 0
# position == 0
# Start: 12, End: 12
# Position: 30
# T: nfflglebzwnknkitzopblefynwqigxfozozviacjrkdcutmrvii, i: 477
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 0
# position == 0
# Start: 8, End: 8
# Position: 7
# T: hbwyqdhqrzdozuvnfodkdqwldkauwvbbuhzityitqfuzgpgsrdltncthwejhgxhfdgerolxdqabngvawdxuadsdeajirmkmobmfqcwyicqpfbsemfihp, i: 478
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 14
# T: dozrroeasfdjqdyatwiekdpwvtxivnyblutwtvpmqwpvapddrqcsxihscblatlkmrncqcigrdopruauukpeymnijokuwmf, i: 479
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 5
# T: jxzsgkeovjuqzlnlhtdbqzxvkpnfknfgehyazrcsyaaulfiey, i: 480
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 6, End: 6
# Position: 9
# T: snbqckwyknevcxhdwvjqvfkouqcagfniuvhjnzm, i: 481
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 14
# T: aaeqsrkjcfsqzuosifguhnocvsycpckjaoyjynqwlfywdvxubiuawkvpvgjoiphwfo, i: 482
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 0
# position == 0
# Start: 0, End: 0
# Position: 1
# T: qqmctkkbrdlgraacyacqbehiqzjuaqzxbxzsnbowfociyygijidyneogzkvvdtcxqibzvlkykvcx, i: 483
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 0
# position == 0
# Start: 8, End: 10
# Position: 31
# position == middle_block.capacity
# Start: 10, End: 10
# Position: 18
# T: ffilecjzjixlwbafcjrrnoswlajrxxckrmwrhracuawzbnktiwklfaskfvfklkwwsqmqrmmdspjbjj, i: 484
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 3
# T: sofvjkjhutynhiscxtdpqrcclsqkaqrkvdhovpvqelvjtoguacafytwyyabnvkmkrsyiwtmxijprtltymltnqllrynspwdygxnzcfscyooeavwiiupjnpn, i: 485
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 18
# T: fyggvpxvuphxkjheekxqppclryelfdf, i: 486
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 17
# T: fkvmvavnqkziczcjthaxqcoyhxfaeomjkrlpgobkqbulpupcdfcejtcohrrcpeoqlwwmyvoopbweadhqjtkklmqdlhircknodmxyhkaxsfdufkzminp, i: 487
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 8
# T: jhookoejuafaixuvpfjpwrkrjkqwksk, i: 488
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 6, End: 6
# Position: 4
# T: vqydxshosxpktquifiomtlxnfomlqhbezbpmzqcfftaswwlmhsujvhqhyqbutxfkdeztqjfsplbfrbutql, i: 489
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 15
# Position: 22
# T: ltchwtdhalsrxlyqjlizzcciluykddeidvdxxgnubwwrqhttvntyv, i: 490
# Start: 0, End: 15
# Position: 23
# T: gpoedpcfbposzcyzgwjcmtdwgffhyfivzfahvbojiqwsbnusqbibrtzuttfqtigiauodrmnjwyzfkou, i: 491
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 3
# T: xrfjumhlbepbkdcpfhmfzxhghcnqccynxcgdwnbqnyweohwibtitwv, i: 492
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 12, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 14, End: 15
# Position: 24
# T: hcqvriyhceyffpgekvuyyjnvirsxigzwbihzjcremubgsaqgfuzyetch, i: 493
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 0
# position == 0
# Start: 4, End: 4
# Position: 21
# T: ryevwnjiztmzwiosojlydfuulczqducxtnaafurpzsiovmcpaycce, i: 494
# Start: 0, End: 15
# Position: 31
# position == middle_block.capacity
# Start: 8, End: 15
# Position: 10
# T: kiczgjfihdxmyhovbhdgtxrjcwssdufnkenbwivtascqkradlmcboffljjeyqozluck, i: 495
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 4, End: 6
# Position: 31
# position == middle_block.capacity
# Start: 6, End: 6
# Position: 25
# T: ekajhfqzealvkqsxgbfubktlybnwkabeezyqqjqqlcevltbbiltgqjmdtkhqrsypormqungpuyeeaizpiszkmdk, i: 496
# Start: 0, End: 15
# Position: 0
# position == 0
# Start: 0, End: 6
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 31
# position == middle_block.capacity
# Start: 2, End: 2
# Position: 20
# T: ojbfnmugkbrrydpbdxhjfsqqdvnjktoqlramkzzeiepooeuwcgidbldjvyvpmvprdzebakcztbljbhuklshibabtscwgmvewhncvlcnvkyamqzmvw, i: 497
# Start: 0, End: 16
# Position: 31
# position == middle_block.capacity
# Start: 9, End: 16
# Position: 0
# position == 0
# Start: 9, End: 11
# Position: 0
# position == 0
# Start: 9, End: 9
# Position: 8
# T: cuhnprypebydeziuiltawboaopaftylvygkickyqhjhhxhkkzsfwrwtgqzlcqhwqlmmjhjivzzcbdfolakuookolvzmjskypdo, i: 498
# Start: 0, End: 16
# Position: 0
# position == 0
# Start: 0, End: 7
# Position: 0
# position == 0
# Start: 0, End: 2
# Position: 20
# T: eybycyeljbgyvuwqeimcivmushzscwftpofnnifrhtgkteashzldvfebcseewjgxwfgtvcoqmuwjcfnhwqwpjtamugmtowrkdtwe, i: 499
# Start: 0, End: 16
# Position: 0
# position == 0
# Start: 0, End: 7
# Position: 1
#
# Finish.

# %%
#collect data about the functions
import time
import string
import random
import math

#defines the number of times each algorithm will be processed to obtain the average time
num_rounds = 100
PAGE_SIZE   = 4096
RECORD_SIZE = 128

#calculates the executions average time
def avgTime(FileType, func, size):
  t = 0

  filename = f"{FileType.__name__}_{PAGE_SIZE}P_{RECORD_SIZE}R_{size}L.bin"
  S = FileType(filename, PAGE_SIZE, RECORD_SIZE)

  for i in range(num_rounds):
    random.seed(size+i)

    start = time.time()

    if "add"==FileType.__name__:
      T  = "".join( [random.choice(string.ascii_lowercase) for i in range(random.randint(1, RECORD_SIZE-10))])
      FileType.add(T)
      assert FileType.search(T)
    elif "scan"==FileType.__name__:
      FileType.scan(False)
    elif "search"==FileType.__name__:
      randomBlockId= random.randint(1, FileType.blocks)
      block = FileType.read(randomBlockId)
      key = block.getRecord(random.randint(block.size())).read()
      (block_id, rec_id) = FileType.search(key)
      assert randomBlockId== block_id
    elif "rangeSearch"==FileType.__name__:
      blockA = FileType.read(random.randint(1, FileType.blocks))
      keyA = block.getRecord(random.randint(block.size())).read()
      blockB = FileType.read(random.randint(1, FileType.blocks))
      keyB = block.getRecord(random.randint(block.size())).read()

      ret = FileType.rangeSearch(min(keyA,keyB), max(keyA,keyB))
      assert ret
    elif "remove"==FileType.__name__:
      block_id = random.randint(1, FileType.blocks)
      block = FileType.read(block_id)
      blockSize = block.size()
      FileType.remove(block.getRecord(random.randint(block.size())).read())
      block = FileType.read(block_id)
      assert blockSize-1 == block.size()
    end = time.time()
    t += end - start

  return t/num_rounds


#defines the file organization types
fileStructures = [HeapFile]

#defines the algorithms to be processed
algorithms = ["add","scan","search","rangeSearch","remove"]

sizes = [100,200,300,400,500]

mapSizeToTime = dict()
for i in range(len(sizes)):
  print(f"Starting collect {i+1}")

  #map list size to algorithm average time
  for fileType in fileStructures:
    for algorithm in algorithms:
      print(f"  > {fileType.__name__}.{algorithm}")
      mapSizeToTime[f"{fileType.__name__}.{algorithm}##{sizes[i]}"] = avgTime(fileType, algorithm, sizes[i])

print(f"Finish data collection")
# Out:
# Starting collect 1
#   > HeapFile.add
#   > HeapFile.scan
#   > HeapFile.search
#   > HeapFile.rangeSearch
#   > HeapFile.remove
# Starting collect 2
#   > HeapFile.add
#   > HeapFile.scan
#   > HeapFile.search
#   > HeapFile.rangeSearch
#   > HeapFile.remove
# Starting collect 3
#   > HeapFile.add
#   > HeapFile.scan
#   > HeapFile.search
#   > HeapFile.rangeSearch
#   > HeapFile.remove
# Starting collect 4
#   > HeapFile.add
#   > HeapFile.scan
#   > HeapFile.search
#   > HeapFile.rangeSearch
#   > HeapFile.remove
# Starting collect 5
#   > HeapFile.add
#   > HeapFile.scan
#   > HeapFile.search
#   > HeapFile.rangeSearch
#   > HeapFile.remove
# Finish data collection

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame.from_dict(mapSizeToTime, orient='index', columns=['Time'])
df['Algorithm'] = [i.split("##")[0] for i in df.index]
df['Size'] = [int(i.split("##")[1]) for i in df.index]
df

#Defines font size and line width
sns.set(font_scale=1, style="ticks", rc={"lines.linewidth": 2})

#Defines plot size
plt.rcParams['figure.figsize'] = [20, 10]

chart = sns.lineplot(x='Size', y='Time', hue='Algorithm', data=df)

#plt.yscale('log')
fig = plt.figure()
chart.set(xticks=[i for i in df.Size])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df
# Out:
#                                    Time             Algorithm  Size
# HeapFile.add##100          6.103516e-07          HeapFile.add   100
# HeapFile.scan##100         6.175041e-07         HeapFile.scan   100
# HeapFile.search##100       7.319450e-07       HeapFile.search   100
# HeapFile.rangeSearch##100  7.867813e-07  HeapFile.rangeSearch   100
# HeapFile.remove##100       7.224083e-07       HeapFile.remove   100
# HeapFile.add##200          7.343292e-07          HeapFile.add   200
# HeapFile.scan##200         7.534027e-07         HeapFile.scan   200
# HeapFile.search##200       7.677078e-07       HeapFile.search   200
# HeapFile.rangeSearch##200  6.914139e-07  HeapFile.rangeSearch   200
# HeapFile.remove##200       6.866455e-07       HeapFile.remove   200
# HeapFile.add##300          7.319450e-07          HeapFile.add   300
# HeapFile.scan##300         7.247925e-07         HeapFile.scan   300
# HeapFile.search##300       7.557869e-07       HeapFile.search   300
# HeapFile.rangeSearch##300  7.104874e-07  HeapFile.rangeSearch   300
# HeapFile.remove##300       7.104874e-07       HeapFile.remove   300
# HeapFile.add##400          7.247925e-07          HeapFile.add   400
# HeapFile.scan##400         7.152557e-07         HeapFile.scan   400
# HeapFile.search##400       7.009506e-07       HeapFile.search   400
# HeapFile.rangeSearch##400  7.009506e-07  HeapFile.rangeSearch   400
# HeapFile.remove##400       7.700920e-07       HeapFile.remove   400
# HeapFile.add##500          7.224083e-07          HeapFile.add   500
# HeapFile.scan##500         7.081032e-07         HeapFile.scan   500
# HeapFile.search##500       7.057190e-07       HeapFile.search   500
# HeapFile.rangeSearch##500  7.128716e-07  HeapFile.rangeSearch   500
# HeapFile.remove##500       7.486343e-07       HeapFile.remove   500
